# %%
import pandas as pd

xls = pd.ExcelFile("data/Skills.xlsx")
print(xls.sheet_names)

df = pd.read_excel("data/Skills.xlsx", sheet_name=xls.sheet_names[0])
print(df.columns)
# Out:
# ['Skills']
# Index(['O*NET-SOC Code', 'Title', 'Element ID', 'Element Name', 'Scale ID',
#        'Scale Name', 'Data Value', 'N', 'Standard Error', 'Lower CI Bound',
#        'Upper CI Bound', 'Recommend Suppress', 'Not Relevant', 'Date',
#        'Domain Source'],
#       dtype='object')

# %%
xls = pd.ExcelFile("data/Occupation Data.xlsx")
print(xls.sheet_names)

df = pd.read_excel("data/Occupation Data.xlsx", sheet_name=xls.sheet_names[0])
print(df.columns)
# Out:
# ['Occupation Data']
# Index(['O*NET-SOC Code', 'Title', 'Description'], dtype='object')
